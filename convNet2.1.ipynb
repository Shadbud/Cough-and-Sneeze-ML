# %%
import tensorflow
from tensorflow.keras.layers import Activation, Dense, Dropout, Conv2D, \
                         Flatten, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
import librosa
import librosa.display
import numpy as np
import pandas as pd
import random
import os

import warnings
warnings.filterwarnings('ignore')

# %%
# Read Data
#audio_dataset_path = r"C:\Users\globb\Desktop\Final dataset\audio\\"
audio_dataset_path = r"E:\Final 2Dataset2\audio\\"
#metadata = pd.read_csv(r'C:\Users\globb\Desktop\Final dataset\metadata.csv')
metadata = pd.read_csv(r'E:\Final 2Dataset2\metadata_clear.csv')
metadata.head(5)
# Out:
#             filename                             path  classid
# 0   1-19111-A-24.wav  E:\Final 2Dataset2\cough_clear\        1
# 1   1-30830-A-24.wav  E:\Final 2Dataset2\cough_clear\        1
# 2   1-52323-A-24.wav  E:\Final 2Dataset2\cough_clear\        1
# 3   1-63679-A-24.wav  E:\Final 2Dataset2\cough_clear\        1
# 4  2-108017-A-24.wav  E:\Final 2Dataset2\cough_clear\        1

# %%
#get ps.shape for different durations
#y, sr = librosa.load(r"C:\Users\globb\Desktop\Final dataset\audio\audioset_CsNTOw4LTBw_100_105.wav", duration=4)
y, sr = librosa.load(r"C:\Users\globb\Desktop\Final dataset\audio\audioset_4lOXjW8rpxU_0_5.wav", duration=4)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
print(sr)
ps.shape
# Out:
# 22050
# (128, 173)

# %%
librosa.display.specshow(ps)

# %%
S_DB = librosa.power_to_db(ps, ref=np.max)
#librosa.display.specshow(S_DB, sr=sr, x_axis='time', y_axis='mel');
librosa.display.specshow(S_DB);

# %%
#Get melspectogram for normal dataset
from tqdm import tqdm
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),str(row["filename"]))
    final_class_labels = row["classid"]
    y, sr = librosa.load(file_name, duration=4) 
    ps = librosa.feature.melspectrogram(y=y, sr=sr)
    ps = librosa.power_to_db(ps, ref=np.max) # Converts melspectogram into dB instead of Amplitude squared
    if ps.shape != (128, 173): continue
    extracted_features.append([ps,final_class_labels])
# Out:
# 636it [01:27,  7.23it/s]

# %%
# Read Augmented Data
augmented_dataset_path = r"E:\Final 2Dataset2\augmented_data\\"
metadata = pd.read_csv(r'E:\Final 2Dataset2\metadata_augmented.csv')
metadata.head(5)
# Out:
#                              filename category  classid
# 0      1-19111-A-24.wavcough_gain.wav    cough        1
# 1     1-19111-A-24.wavcough_noise.wav    cough        1
# 2     1-19111-A-24.wavcough_pitch.wav    cough        1
# 3  1-19111-A-24.wavcough_polarity.wav    cough        1
# 4      1-30830-A-24.wavcough_gain.wav    cough        1

# %%
#Get melspectogram for augmented dataset
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(augmented_dataset_path),str(row["filename"]))
    final_class_labels = row["classid"]
    y, sr = librosa.load(file_name, duration=4, sr=16000) 
    ps = librosa.feature.melspectrogram(y=y, sr=sr)
    ps = librosa.power_to_db(ps, ref=np.max) # Converts melspectogram into dB instead of Amplitude squared
    if ps.shape != (128, 126): continue
    extracted_features.append([ps,final_class_labels])
# Out:
# 1696it [01:27, 19.37it/s]

# %%
#Read "other" non augmented data
other_dataset_path = r"E:\Final 2Dataset2\other_not_augmented\\"
metadata = pd.read_csv(r'E:\Final 2Dataset2\metadata_other.csv')
metadata.head(5)
# Out:
#                   filename  classid
# 0   esc50_2-100786-A-1.wav        3
# 1  esc50_2-102414-A-17.wav        3
# 2  esc50_2-102414-B-17.wav        3
# 3  esc50_2-102414-E-17.wav        3
# 4  esc50_2-102414-G-17.wav        3

# %%
#Get melspectogram for other not augmented
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(other_dataset_path),str(row["filename"]))
    final_class_labels = row["classid"]
    y, sr = librosa.load(file_name, duration=4, sr=16000) 
    ps = librosa.feature.melspectrogram(y=y, sr=sr)
    ps = librosa.power_to_db(ps, ref=np.max) # Converts melspectogram into dB instead of Amplitude squared
    if ps.shape != (128, 126): continue
    extracted_features.append([ps,final_class_labels])
# Out:
# 848it [01:21, 10.37it/s]

# %%
print("Number of samples: ", len(extracted_features))
# Out:
# Number of samples:  636

# %%
dataset = extracted_features
random.shuffle(dataset)

train = dataset[:504]#2226 for augmented
test = dataset[504:]

X_train, y_train = zip(*train)
X_test, y_test = zip(*test)

# %%
# Reshape for CNN input
X_train = np.array([x.reshape( (128, 173, 1) ) for x in X_train])
X_test = np.array([x.reshape( (128, 173, 1) ) for x in X_test])

# %%
# One-Hot encoding for classes
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y_train = tensorflow.keras.utils.to_categorical(labelencoder.fit_transform(y_train))
y_test = np.array(tensorflow.keras.utils.to_categorical(labelencoder.fit_transform(y_test)))

# %%
X_train.shape
# Out:
# (504, 128, 173, 1)

# %%
y_train.shape
# Out:
# (504, 3)

# %%
import matplotlib.pyplot as plt

# %%
def plot_history(history):
    
    fig, axs = plt.subplots(2,constrained_layout=True)

    #create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    #create error subplot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
print("Num GPUs Available: ", len(tensorflow.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from keras.layers import LeakyReLU

# %%
model = Sequential()
input_shape=(128, 173, 1)

model.add(Conv2D(24, (5, 5), strides=(1, 1), input_shape=input_shape, kernel_regularizer=regularizers.L2(0.001)))
model.add(MaxPooling2D((4, 2), strides=(4, 2)))
model.add(LeakyReLU(alpha=0.05))

model.add(Conv2D(48, (5, 5), padding="valid", kernel_regularizer=regularizers.L2(0.001)))
model.add(MaxPooling2D((4, 2), strides=(4, 2)))
model.add(LeakyReLU(alpha=0.05))

model.add(Conv2D(48, (5, 5), padding="valid", kernel_regularizer=regularizers.L2(0.001)))
model.add(LeakyReLU(alpha=0.05))

model.add(Flatten())
model.add(Dropout(rate=0.4))

model.add(Dense(64, kernel_regularizer=regularizers.L2(0.008)))
model.add(LeakyReLU(alpha=0.05))
model.add(Dropout(rate=0.4))

model.add(Dense(3))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
model.save('saved_models/audio_classifier_portable')

## Trianing my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 250
num_batch_size = 64

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=False)
start = datetime.now()

history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
plot_history(history)

score = model.evaluate(
	X_test,
	y_test)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# INFO:tensorflow:Assets written to: saved_models/audio_classifier_portable\assets
# Epoch 1/250
# 8/8 [==============================] - 2s 89ms/step - loss: 6.9323 - accuracy: 0.2798 - val_loss: 2.1597 - val_accuracy: 0.3636
#
# Epoch 00001: saving model to saved_models\audio_classification.hdf5
# Epoch 2/250
# 8/8 [==============================] - 0s 30ms/step - loss: 2.2513 - accuracy: 0.3274 - val_loss: 2.1699 - val_accuracy: 0.3106
#
# Epoch 00002: saving model to saved_models\audio_classification.hdf5
# Epoch 3/250
# 8/8 [==============================] - 0s 30ms/step - loss: 2.1664 - accuracy: 0.3730 - val_loss: 2.1330 - val_accuracy: 0.4621
#
# Epoch 00003: saving model to saved_models\audio_classification.hdf5
# Epoch 4/250
# 8/8 [==============================] - 0s 30ms/step - loss: 2.1505 - accuracy: 0.3492 - val_loss: 2.0956 - val_accuracy: 0.3636
#
# Epoch 00004: saving model to saved_models\audio_classification.hdf5
# Epoch 5/250
# 8/8 [==============================] - 0s 31ms/step - loss: 2.0673 - accuracy: 0.4306 - val_loss: 2.0170 - val_accuracy: 0.4773
#
# Epoch 00005: saving model to saved_models\audio_classification.hdf5
# Epoch 6/250
# 8/8 [==============================] - 0s 30ms/step - loss: 2.0455 - accuracy: 0.4107 - val_loss: 1.9495 - val_accuracy: 0.5606
#
# Epoch 00006: saving model to saved_models\audio_classification.hdf5
# Epoch 7/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.9444 - accuracy: 0.5119 - val_loss: 1.8556 - val_accuracy: 0.6364
#
# Epoch 00007: saving model to saved_models\audio_classification.hdf5
# Epoch 8/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.8664 - accuracy: 0.5714 - val_loss: 1.8009 - val_accuracy: 0.6667
#
# Epoch 00008: saving model to saved_models\audio_classification.hdf5
# Epoch 9/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.7988 - accuracy: 0.6171 - val_loss: 1.7827 - val_accuracy: 0.5227
#
# Epoch 00009: saving model to saved_models\audio_classification.hdf5
# Epoch 10/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.7639 - accuracy: 0.6349 - val_loss: 1.7321 - val_accuracy: 0.5985
#
# Epoch 00010: saving model to saved_models\audio_classification.hdf5
# Epoch 11/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.6694 - accuracy: 0.6548 - val_loss: 1.6271 - val_accuracy: 0.6742
#
# Epoch 00011: saving model to saved_models\audio_classification.hdf5
# Epoch 12/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.5898 - accuracy: 0.6925 - val_loss: 1.5466 - val_accuracy: 0.7879
#
# Epoch 00012: saving model to saved_models\audio_classification.hdf5
# Epoch 13/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.5286 - accuracy: 0.7123 - val_loss: 1.4972 - val_accuracy: 0.6667
#
# Epoch 00013: saving model to saved_models\audio_classification.hdf5
# Epoch 14/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.5028 - accuracy: 0.6905 - val_loss: 1.4897 - val_accuracy: 0.7197
#
# Epoch 00014: saving model to saved_models\audio_classification.hdf5
# Epoch 15/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.5429 - accuracy: 0.6706 - val_loss: 1.7207 - val_accuracy: 0.6742
#
# Epoch 00015: saving model to saved_models\audio_classification.hdf5
# Epoch 16/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.4879 - accuracy: 0.6905 - val_loss: 1.4670 - val_accuracy: 0.7424
#
# Epoch 00016: saving model to saved_models\audio_classification.hdf5
# Epoch 17/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.4106 - accuracy: 0.7202 - val_loss: 1.4879 - val_accuracy: 0.7197
#
# Epoch 00017: saving model to saved_models\audio_classification.hdf5
# Epoch 18/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.3820 - accuracy: 0.7262 - val_loss: 1.5229 - val_accuracy: 0.7348
#
# Epoch 00018: saving model to saved_models\audio_classification.hdf5
# Epoch 19/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.2943 - accuracy: 0.7639 - val_loss: 1.3660 - val_accuracy: 0.7803
#
# Epoch 00019: saving model to saved_models\audio_classification.hdf5
# Epoch 20/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.2622 - accuracy: 0.7718 - val_loss: 1.3615 - val_accuracy: 0.7348
#
# Epoch 00020: saving model to saved_models\audio_classification.hdf5
# Epoch 21/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.2310 - accuracy: 0.8016 - val_loss: 1.3129 - val_accuracy: 0.8030
#
# Epoch 00021: saving model to saved_models\audio_classification.hdf5
# Epoch 22/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.1872 - accuracy: 0.8095 - val_loss: 1.3387 - val_accuracy: 0.7576
#
# Epoch 00022: saving model to saved_models\audio_classification.hdf5
# Epoch 23/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.1763 - accuracy: 0.7976 - val_loss: 1.3447 - val_accuracy: 0.7348
#
# Epoch 00023: saving model to saved_models\audio_classification.hdf5
# Epoch 24/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0999 - accuracy: 0.8433 - val_loss: 1.2859 - val_accuracy: 0.7500
#
# Epoch 00024: saving model to saved_models\audio_classification.hdf5
# Epoch 25/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0707 - accuracy: 0.8452 - val_loss: 1.3504 - val_accuracy: 0.7727
#
# Epoch 00025: saving model to saved_models\audio_classification.hdf5
# Epoch 26/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0522 - accuracy: 0.8552 - val_loss: 1.2417 - val_accuracy: 0.7803
#
# Epoch 00026: saving model to saved_models\audio_classification.hdf5
# Epoch 27/250
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0247 - accuracy: 0.8651 - val_loss: 1.2547 - val_accuracy: 0.7424
#
# Epoch 00027: saving model to saved_models\audio_classification.hdf5
# Epoch 28/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.9792 - accuracy: 0.8631 - val_loss: 1.2361 - val_accuracy: 0.7500
#
# Epoch 00028: saving model to saved_models\audio_classification.hdf5
# Epoch 29/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.9352 - accuracy: 0.8948 - val_loss: 1.2147 - val_accuracy: 0.7955
#
# Epoch 00029: saving model to saved_models\audio_classification.hdf5
# Epoch 30/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.9196 - accuracy: 0.8849 - val_loss: 1.2130 - val_accuracy: 0.7727
#
# Epoch 00030: saving model to saved_models\audio_classification.hdf5
# Epoch 31/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8693 - accuracy: 0.9087 - val_loss: 1.1798 - val_accuracy: 0.7652
#
# Epoch 00031: saving model to saved_models\audio_classification.hdf5
# Epoch 32/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8061 - accuracy: 0.9206 - val_loss: 1.2416 - val_accuracy: 0.7576
#
# Epoch 00032: saving model to saved_models\audio_classification.hdf5
# Epoch 33/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8563 - accuracy: 0.9048 - val_loss: 1.0853 - val_accuracy: 0.8333
#
# Epoch 00033: saving model to saved_models\audio_classification.hdf5
# Epoch 34/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7683 - accuracy: 0.9444 - val_loss: 1.0866 - val_accuracy: 0.8030
#
# Epoch 00034: saving model to saved_models\audio_classification.hdf5
# Epoch 35/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7560 - accuracy: 0.9385 - val_loss: 1.2224 - val_accuracy: 0.7424
#
# Epoch 00035: saving model to saved_models\audio_classification.hdf5
# Epoch 36/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7945 - accuracy: 0.9345 - val_loss: 1.3079 - val_accuracy: 0.7576
#
# Epoch 00036: saving model to saved_models\audio_classification.hdf5
# Epoch 37/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8609 - accuracy: 0.8948 - val_loss: 1.2864 - val_accuracy: 0.6818
#
# Epoch 00037: saving model to saved_models\audio_classification.hdf5
# Epoch 38/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7854 - accuracy: 0.9127 - val_loss: 1.3193 - val_accuracy: 0.7348
#
# Epoch 00038: saving model to saved_models\audio_classification.hdf5
# Epoch 39/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7568 - accuracy: 0.9266 - val_loss: 1.1797 - val_accuracy: 0.8106
#
# Epoch 00039: saving model to saved_models\audio_classification.hdf5
# Epoch 40/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7313 - accuracy: 0.9524 - val_loss: 1.2621 - val_accuracy: 0.7576
#
# Epoch 00040: saving model to saved_models\audio_classification.hdf5
# Epoch 41/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7097 - accuracy: 0.9484 - val_loss: 1.1263 - val_accuracy: 0.7727
#
# Epoch 00041: saving model to saved_models\audio_classification.hdf5
# Epoch 42/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6877 - accuracy: 0.9583 - val_loss: 1.1282 - val_accuracy: 0.8106
#
# Epoch 00042: saving model to saved_models\audio_classification.hdf5
# Epoch 43/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6590 - accuracy: 0.9643 - val_loss: 1.0632 - val_accuracy: 0.8030
#
# Epoch 00043: saving model to saved_models\audio_classification.hdf5
# Epoch 44/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6574 - accuracy: 0.9563 - val_loss: 1.2078 - val_accuracy: 0.7652
#
# Epoch 00044: saving model to saved_models\audio_classification.hdf5
# Epoch 45/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6272 - accuracy: 0.9663 - val_loss: 1.1353 - val_accuracy: 0.7652
#
# Epoch 00045: saving model to saved_models\audio_classification.hdf5
# Epoch 46/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6416 - accuracy: 0.9524 - val_loss: 1.3860 - val_accuracy: 0.6970
#
# Epoch 00046: saving model to saved_models\audio_classification.hdf5
# Epoch 47/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6377 - accuracy: 0.9504 - val_loss: 0.9822 - val_accuracy: 0.8333
#
# Epoch 00047: saving model to saved_models\audio_classification.hdf5
# Epoch 48/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6797 - accuracy: 0.9405 - val_loss: 0.9906 - val_accuracy: 0.8409
#
# Epoch 00048: saving model to saved_models\audio_classification.hdf5
# Epoch 49/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7202 - accuracy: 0.9067 - val_loss: 1.2095 - val_accuracy: 0.7197
#
# Epoch 00049: saving model to saved_models\audio_classification.hdf5
# Epoch 50/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6974 - accuracy: 0.9246 - val_loss: 1.1656 - val_accuracy: 0.7500
#
# Epoch 00050: saving model to saved_models\audio_classification.hdf5
# Epoch 51/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6378 - accuracy: 0.9583 - val_loss: 1.1482 - val_accuracy: 0.7879
#
# Epoch 00051: saving model to saved_models\audio_classification.hdf5
# Epoch 52/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6573 - accuracy: 0.9425 - val_loss: 1.1711 - val_accuracy: 0.7727
#
# Epoch 00052: saving model to saved_models\audio_classification.hdf5
# Epoch 53/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6097 - accuracy: 0.9683 - val_loss: 1.1219 - val_accuracy: 0.8030
#
# Epoch 00053: saving model to saved_models\audio_classification.hdf5
# Epoch 54/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5845 - accuracy: 0.9643 - val_loss: 1.1173 - val_accuracy: 0.7727
#
# Epoch 00054: saving model to saved_models\audio_classification.hdf5
# Epoch 55/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5655 - accuracy: 0.9722 - val_loss: 1.2469 - val_accuracy: 0.7652
#
# Epoch 00055: saving model to saved_models\audio_classification.hdf5
# Epoch 56/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5778 - accuracy: 0.9683 - val_loss: 1.1945 - val_accuracy: 0.7424
#
# Epoch 00056: saving model to saved_models\audio_classification.hdf5
# Epoch 57/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5448 - accuracy: 0.9762 - val_loss: 0.9647 - val_accuracy: 0.8485
#
# Epoch 00057: saving model to saved_models\audio_classification.hdf5
# Epoch 58/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5269 - accuracy: 0.9802 - val_loss: 1.2362 - val_accuracy: 0.7576
#
# Epoch 00058: saving model to saved_models\audio_classification.hdf5
# Epoch 59/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5349 - accuracy: 0.9722 - val_loss: 0.9913 - val_accuracy: 0.8182
#
# Epoch 00059: saving model to saved_models\audio_classification.hdf5
# Epoch 60/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5012 - accuracy: 0.9881 - val_loss: 1.0450 - val_accuracy: 0.7955
#
# Epoch 00060: saving model to saved_models\audio_classification.hdf5
# Epoch 61/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4988 - accuracy: 0.9921 - val_loss: 1.0926 - val_accuracy: 0.7955
#
# Epoch 00061: saving model to saved_models\audio_classification.hdf5
# Epoch 62/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4966 - accuracy: 0.9821 - val_loss: 1.0397 - val_accuracy: 0.8106
#
# Epoch 00062: saving model to saved_models\audio_classification.hdf5
# Epoch 63/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4919 - accuracy: 0.9782 - val_loss: 1.1409 - val_accuracy: 0.7803
#
# Epoch 00063: saving model to saved_models\audio_classification.hdf5
# Epoch 64/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4796 - accuracy: 0.9821 - val_loss: 1.0270 - val_accuracy: 0.8182
#
# Epoch 00064: saving model to saved_models\audio_classification.hdf5
# Epoch 65/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4692 - accuracy: 0.9861 - val_loss: 1.0441 - val_accuracy: 0.8106
#
# Epoch 00065: saving model to saved_models\audio_classification.hdf5
# Epoch 66/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4943 - accuracy: 0.9782 - val_loss: 1.0280 - val_accuracy: 0.7955
#
# Epoch 00066: saving model to saved_models\audio_classification.hdf5
# Epoch 67/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4835 - accuracy: 0.9782 - val_loss: 0.9276 - val_accuracy: 0.8485
#
# Epoch 00067: saving model to saved_models\audio_classification.hdf5
# Epoch 68/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4772 - accuracy: 0.9782 - val_loss: 1.0346 - val_accuracy: 0.7879
#
# Epoch 00068: saving model to saved_models\audio_classification.hdf5
# Epoch 69/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4665 - accuracy: 0.9802 - val_loss: 1.0714 - val_accuracy: 0.7803
#
# Epoch 00069: saving model to saved_models\audio_classification.hdf5
# Epoch 70/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4553 - accuracy: 0.9821 - val_loss: 0.9436 - val_accuracy: 0.8636
#
# Epoch 00070: saving model to saved_models\audio_classification.hdf5
# Epoch 71/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4427 - accuracy: 0.9841 - val_loss: 1.0503 - val_accuracy: 0.8030
#
# Epoch 00071: saving model to saved_models\audio_classification.hdf5
# Epoch 72/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4383 - accuracy: 0.9901 - val_loss: 0.9722 - val_accuracy: 0.8333
#
# Epoch 00072: saving model to saved_models\audio_classification.hdf5
# Epoch 73/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4522 - accuracy: 0.9762 - val_loss: 1.4264 - val_accuracy: 0.7424
#
# Epoch 00073: saving model to saved_models\audio_classification.hdf5
# Epoch 74/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5464 - accuracy: 0.9405 - val_loss: 1.3924 - val_accuracy: 0.6818
#
# Epoch 00074: saving model to saved_models\audio_classification.hdf5
# Epoch 75/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5429 - accuracy: 0.9504 - val_loss: 1.0249 - val_accuracy: 0.8182
#
# Epoch 00075: saving model to saved_models\audio_classification.hdf5
# Epoch 76/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4831 - accuracy: 0.9583 - val_loss: 1.2013 - val_accuracy: 0.7348
#
# Epoch 00076: saving model to saved_models\audio_classification.hdf5
# Epoch 77/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4657 - accuracy: 0.9762 - val_loss: 1.0066 - val_accuracy: 0.8030
#
# Epoch 00077: saving model to saved_models\audio_classification.hdf5
# Epoch 78/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4685 - accuracy: 0.9722 - val_loss: 1.1906 - val_accuracy: 0.7652
#
# Epoch 00078: saving model to saved_models\audio_classification.hdf5
# Epoch 79/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4830 - accuracy: 0.9683 - val_loss: 1.2263 - val_accuracy: 0.7652
#
# Epoch 00079: saving model to saved_models\audio_classification.hdf5
# Epoch 80/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4770 - accuracy: 0.9643 - val_loss: 1.1875 - val_accuracy: 0.7803
#
# Epoch 00080: saving model to saved_models\audio_classification.hdf5
# Epoch 81/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4524 - accuracy: 0.9782 - val_loss: 1.0092 - val_accuracy: 0.7955
#
# Epoch 00081: saving model to saved_models\audio_classification.hdf5
# Epoch 82/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4541 - accuracy: 0.9702 - val_loss: 1.1228 - val_accuracy: 0.8030
#
# Epoch 00082: saving model to saved_models\audio_classification.hdf5
# Epoch 83/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4584 - accuracy: 0.9861 - val_loss: 1.0950 - val_accuracy: 0.8030
#
# Epoch 00083: saving model to saved_models\audio_classification.hdf5
# Epoch 84/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4258 - accuracy: 0.9861 - val_loss: 1.1964 - val_accuracy: 0.7803
#
# Epoch 00084: saving model to saved_models\audio_classification.hdf5
# Epoch 85/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4011 - accuracy: 0.9940 - val_loss: 1.1011 - val_accuracy: 0.8030
#
# Epoch 00085: saving model to saved_models\audio_classification.hdf5
# Epoch 86/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4139 - accuracy: 0.9861 - val_loss: 1.2270 - val_accuracy: 0.7955
#
# Epoch 00086: saving model to saved_models\audio_classification.hdf5
# Epoch 87/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4077 - accuracy: 0.9861 - val_loss: 1.1059 - val_accuracy: 0.8030
#
# Epoch 00087: saving model to saved_models\audio_classification.hdf5
# Epoch 88/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4236 - accuracy: 0.9762 - val_loss: 0.9987 - val_accuracy: 0.8258
#
# Epoch 00088: saving model to saved_models\audio_classification.hdf5
# Epoch 89/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4111 - accuracy: 0.9742 - val_loss: 1.3694 - val_accuracy: 0.7273
#
# Epoch 00089: saving model to saved_models\audio_classification.hdf5
# Epoch 90/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4064 - accuracy: 0.9841 - val_loss: 0.9959 - val_accuracy: 0.8182
#
# Epoch 00090: saving model to saved_models\audio_classification.hdf5
# Epoch 91/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3995 - accuracy: 0.9861 - val_loss: 1.2175 - val_accuracy: 0.8030
#
# Epoch 00091: saving model to saved_models\audio_classification.hdf5
# Epoch 92/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4057 - accuracy: 0.9841 - val_loss: 1.0488 - val_accuracy: 0.8258
#
# Epoch 00092: saving model to saved_models\audio_classification.hdf5
# Epoch 93/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3779 - accuracy: 0.9921 - val_loss: 0.9158 - val_accuracy: 0.8333
#
# Epoch 00093: saving model to saved_models\audio_classification.hdf5
# Epoch 94/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3600 - accuracy: 0.9960 - val_loss: 0.9247 - val_accuracy: 0.8182
#
# Epoch 00094: saving model to saved_models\audio_classification.hdf5
# Epoch 95/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3694 - accuracy: 0.9881 - val_loss: 0.9141 - val_accuracy: 0.8182
#
# Epoch 00095: saving model to saved_models\audio_classification.hdf5
# Epoch 96/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3717 - accuracy: 0.9861 - val_loss: 0.9725 - val_accuracy: 0.7955
#
# Epoch 00096: saving model to saved_models\audio_classification.hdf5
# Epoch 97/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3684 - accuracy: 0.9861 - val_loss: 1.0241 - val_accuracy: 0.7955
#
# Epoch 00097: saving model to saved_models\audio_classification.hdf5
# Epoch 98/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3514 - accuracy: 0.9921 - val_loss: 0.9984 - val_accuracy: 0.8106
#
# Epoch 00098: saving model to saved_models\audio_classification.hdf5
# Epoch 99/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3548 - accuracy: 0.9861 - val_loss: 1.0098 - val_accuracy: 0.7727
#
# Epoch 00099: saving model to saved_models\audio_classification.hdf5
# Epoch 100/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3426 - accuracy: 0.9960 - val_loss: 0.8895 - val_accuracy: 0.8258
#
# Epoch 00100: saving model to saved_models\audio_classification.hdf5
# Epoch 101/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3416 - accuracy: 0.9940 - val_loss: 1.0532 - val_accuracy: 0.7955
#
# Epoch 00101: saving model to saved_models\audio_classification.hdf5
# Epoch 102/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3492 - accuracy: 0.9841 - val_loss: 0.9994 - val_accuracy: 0.8030
#
# Epoch 00102: saving model to saved_models\audio_classification.hdf5
# Epoch 103/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3384 - accuracy: 0.9901 - val_loss: 0.9946 - val_accuracy: 0.8182
#
# Epoch 00103: saving model to saved_models\audio_classification.hdf5
# Epoch 104/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3490 - accuracy: 0.9881 - val_loss: 0.9151 - val_accuracy: 0.8333
#
# Epoch 00104: saving model to saved_models\audio_classification.hdf5
# Epoch 105/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3496 - accuracy: 0.9841 - val_loss: 1.0083 - val_accuracy: 0.8030
#
# Epoch 00105: saving model to saved_models\audio_classification.hdf5
# Epoch 106/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3448 - accuracy: 0.9921 - val_loss: 1.0329 - val_accuracy: 0.8106
#
# Epoch 00106: saving model to saved_models\audio_classification.hdf5
# Epoch 107/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4258 - accuracy: 0.9544 - val_loss: 1.1560 - val_accuracy: 0.7803
#
# Epoch 00107: saving model to saved_models\audio_classification.hdf5
# Epoch 108/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4018 - accuracy: 0.9742 - val_loss: 1.1227 - val_accuracy: 0.7803
#
# Epoch 00108: saving model to saved_models\audio_classification.hdf5
# Epoch 109/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3755 - accuracy: 0.9762 - val_loss: 0.9172 - val_accuracy: 0.8485
#
# Epoch 00109: saving model to saved_models\audio_classification.hdf5
# Epoch 110/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3599 - accuracy: 0.9782 - val_loss: 0.8474 - val_accuracy: 0.8636
#
# Epoch 00110: saving model to saved_models\audio_classification.hdf5
# Epoch 111/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3668 - accuracy: 0.9821 - val_loss: 0.8180 - val_accuracy: 0.8485
#
# Epoch 00111: saving model to saved_models\audio_classification.hdf5
# Epoch 112/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3664 - accuracy: 0.9841 - val_loss: 0.8863 - val_accuracy: 0.8258
#
# Epoch 00112: saving model to saved_models\audio_classification.hdf5
# Epoch 113/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3672 - accuracy: 0.9881 - val_loss: 0.9546 - val_accuracy: 0.8258
#
# Epoch 00113: saving model to saved_models\audio_classification.hdf5
# Epoch 114/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3659 - accuracy: 0.9861 - val_loss: 1.1353 - val_accuracy: 0.7803
#
# Epoch 00114: saving model to saved_models\audio_classification.hdf5
# Epoch 115/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3497 - accuracy: 0.9861 - val_loss: 0.8196 - val_accuracy: 0.8561
#
# Epoch 00115: saving model to saved_models\audio_classification.hdf5
# Epoch 116/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3394 - accuracy: 0.9901 - val_loss: 0.8434 - val_accuracy: 0.8333
#
# Epoch 00116: saving model to saved_models\audio_classification.hdf5
# Epoch 117/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3316 - accuracy: 0.9901 - val_loss: 0.9017 - val_accuracy: 0.8182
#
# Epoch 00117: saving model to saved_models\audio_classification.hdf5
# Epoch 118/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3223 - accuracy: 0.9960 - val_loss: 0.8628 - val_accuracy: 0.8333
#
# Epoch 00118: saving model to saved_models\audio_classification.hdf5
# Epoch 119/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3238 - accuracy: 0.9960 - val_loss: 0.9653 - val_accuracy: 0.8106
#
# Epoch 00119: saving model to saved_models\audio_classification.hdf5
# Epoch 120/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3056 - accuracy: 0.9980 - val_loss: 0.9072 - val_accuracy: 0.8258
#
# Epoch 00120: saving model to saved_models\audio_classification.hdf5
# Epoch 121/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3392 - accuracy: 0.9802 - val_loss: 0.9230 - val_accuracy: 0.8258
#
# Epoch 00121: saving model to saved_models\audio_classification.hdf5
# Epoch 122/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3261 - accuracy: 0.9821 - val_loss: 0.8420 - val_accuracy: 0.8485
#
# Epoch 00122: saving model to saved_models\audio_classification.hdf5
# Epoch 123/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3253 - accuracy: 0.9821 - val_loss: 0.7676 - val_accuracy: 0.8409
#
# Epoch 00123: saving model to saved_models\audio_classification.hdf5
# Epoch 124/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3199 - accuracy: 0.9861 - val_loss: 1.0094 - val_accuracy: 0.7727
#
# Epoch 00124: saving model to saved_models\audio_classification.hdf5
# Epoch 125/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3131 - accuracy: 0.9901 - val_loss: 0.7609 - val_accuracy: 0.8864
#
# Epoch 00125: saving model to saved_models\audio_classification.hdf5
# Epoch 126/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3428 - accuracy: 0.9861 - val_loss: 0.9074 - val_accuracy: 0.8561
#
# Epoch 00126: saving model to saved_models\audio_classification.hdf5
# Epoch 127/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3222 - accuracy: 0.9901 - val_loss: 1.1706 - val_accuracy: 0.7879
#
# Epoch 00127: saving model to saved_models\audio_classification.hdf5
# Epoch 128/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3091 - accuracy: 0.9940 - val_loss: 0.9742 - val_accuracy: 0.8182
#
# Epoch 00128: saving model to saved_models\audio_classification.hdf5
# Epoch 129/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3056 - accuracy: 0.9921 - val_loss: 0.8836 - val_accuracy: 0.8333
#
# Epoch 00129: saving model to saved_models\audio_classification.hdf5
# Epoch 130/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2904 - accuracy: 0.9940 - val_loss: 0.8430 - val_accuracy: 0.8333
#
# Epoch 00130: saving model to saved_models\audio_classification.hdf5
# Epoch 131/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2804 - accuracy: 0.9980 - val_loss: 0.8772 - val_accuracy: 0.8182
#
# Epoch 00131: saving model to saved_models\audio_classification.hdf5
# Epoch 132/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2741 - accuracy: 0.9980 - val_loss: 0.8209 - val_accuracy: 0.8409
#
# Epoch 00132: saving model to saved_models\audio_classification.hdf5
# Epoch 133/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2868 - accuracy: 0.9881 - val_loss: 0.8715 - val_accuracy: 0.8258
#
# Epoch 00133: saving model to saved_models\audio_classification.hdf5
# Epoch 134/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3037 - accuracy: 0.9841 - val_loss: 1.2101 - val_accuracy: 0.7652
#
# Epoch 00134: saving model to saved_models\audio_classification.hdf5
# Epoch 135/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2966 - accuracy: 0.9841 - val_loss: 0.8611 - val_accuracy: 0.8409
#
# Epoch 00135: saving model to saved_models\audio_classification.hdf5
# Epoch 136/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2892 - accuracy: 0.9861 - val_loss: 1.1320 - val_accuracy: 0.8106
#
# Epoch 00136: saving model to saved_models\audio_classification.hdf5
# Epoch 137/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2879 - accuracy: 0.9940 - val_loss: 0.9271 - val_accuracy: 0.8409
#
# Epoch 00137: saving model to saved_models\audio_classification.hdf5
# Epoch 138/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3148 - accuracy: 0.9762 - val_loss: 1.1594 - val_accuracy: 0.7727
#
# Epoch 00138: saving model to saved_models\audio_classification.hdf5
# Epoch 139/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3056 - accuracy: 0.9841 - val_loss: 0.8274 - val_accuracy: 0.8409
#
# Epoch 00139: saving model to saved_models\audio_classification.hdf5
# Epoch 140/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2768 - accuracy: 0.9940 - val_loss: 0.7892 - val_accuracy: 0.8333
#
# Epoch 00140: saving model to saved_models\audio_classification.hdf5
# Epoch 141/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2793 - accuracy: 0.9921 - val_loss: 0.9675 - val_accuracy: 0.8030
#
# Epoch 00141: saving model to saved_models\audio_classification.hdf5
# Epoch 142/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2896 - accuracy: 0.9881 - val_loss: 0.9561 - val_accuracy: 0.7955
#
# Epoch 00142: saving model to saved_models\audio_classification.hdf5
# Epoch 143/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2739 - accuracy: 0.9901 - val_loss: 0.7510 - val_accuracy: 0.8712
#
# Epoch 00143: saving model to saved_models\audio_classification.hdf5
# Epoch 144/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2647 - accuracy: 0.9960 - val_loss: 1.1028 - val_accuracy: 0.7955
#
# Epoch 00144: saving model to saved_models\audio_classification.hdf5
# Epoch 145/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3088 - accuracy: 0.9821 - val_loss: 0.8781 - val_accuracy: 0.8333
#
# Epoch 00145: saving model to saved_models\audio_classification.hdf5
# Epoch 146/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2796 - accuracy: 0.9881 - val_loss: 0.9283 - val_accuracy: 0.7955
#
# Epoch 00146: saving model to saved_models\audio_classification.hdf5
# Epoch 147/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2916 - accuracy: 0.9901 - val_loss: 0.7564 - val_accuracy: 0.8333
#
# Epoch 00147: saving model to saved_models\audio_classification.hdf5
# Epoch 148/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2778 - accuracy: 0.9921 - val_loss: 0.7479 - val_accuracy: 0.8636
#
# Epoch 00148: saving model to saved_models\audio_classification.hdf5
# Epoch 149/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2803 - accuracy: 0.9901 - val_loss: 0.8817 - val_accuracy: 0.8333
#
# Epoch 00149: saving model to saved_models\audio_classification.hdf5
# Epoch 150/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2763 - accuracy: 0.9901 - val_loss: 1.1002 - val_accuracy: 0.7652
#
# Epoch 00150: saving model to saved_models\audio_classification.hdf5
# Epoch 151/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2949 - accuracy: 0.9841 - val_loss: 0.8239 - val_accuracy: 0.8106
#
# Epoch 00151: saving model to saved_models\audio_classification.hdf5
# Epoch 152/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2908 - accuracy: 0.9901 - val_loss: 0.8365 - val_accuracy: 0.8258
#
# Epoch 00152: saving model to saved_models\audio_classification.hdf5
# Epoch 153/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2853 - accuracy: 0.9861 - val_loss: 1.5256 - val_accuracy: 0.7348
#
# Epoch 00153: saving model to saved_models\audio_classification.hdf5
# Epoch 154/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3035 - accuracy: 0.9841 - val_loss: 0.7298 - val_accuracy: 0.8788
#
# Epoch 00154: saving model to saved_models\audio_classification.hdf5
# Epoch 155/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2929 - accuracy: 0.9861 - val_loss: 1.0948 - val_accuracy: 0.7576
#
# Epoch 00155: saving model to saved_models\audio_classification.hdf5
# Epoch 156/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3027 - accuracy: 0.9821 - val_loss: 0.7096 - val_accuracy: 0.8788
#
# Epoch 00156: saving model to saved_models\audio_classification.hdf5
# Epoch 157/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3129 - accuracy: 0.9742 - val_loss: 0.7645 - val_accuracy: 0.8485
#
# Epoch 00157: saving model to saved_models\audio_classification.hdf5
# Epoch 158/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2834 - accuracy: 0.9921 - val_loss: 0.9813 - val_accuracy: 0.7803
#
# Epoch 00158: saving model to saved_models\audio_classification.hdf5
# Epoch 159/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3046 - accuracy: 0.9881 - val_loss: 0.9686 - val_accuracy: 0.8106
#
# Epoch 00159: saving model to saved_models\audio_classification.hdf5
# Epoch 160/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3181 - accuracy: 0.9841 - val_loss: 0.9906 - val_accuracy: 0.8106
#
# Epoch 00160: saving model to saved_models\audio_classification.hdf5
# Epoch 161/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2970 - accuracy: 0.9861 - val_loss: 0.9228 - val_accuracy: 0.8106
#
# Epoch 00161: saving model to saved_models\audio_classification.hdf5
# Epoch 162/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3036 - accuracy: 0.9861 - val_loss: 0.9480 - val_accuracy: 0.8182
#
# Epoch 00162: saving model to saved_models\audio_classification.hdf5
# Epoch 163/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3048 - accuracy: 0.9841 - val_loss: 0.8013 - val_accuracy: 0.8258
#
# Epoch 00163: saving model to saved_models\audio_classification.hdf5
# Epoch 164/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2919 - accuracy: 0.9881 - val_loss: 1.2879 - val_accuracy: 0.7803
#
# Epoch 00164: saving model to saved_models\audio_classification.hdf5
# Epoch 165/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2932 - accuracy: 0.9861 - val_loss: 0.8819 - val_accuracy: 0.8485
#
# Epoch 00165: saving model to saved_models\audio_classification.hdf5
# Epoch 166/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3297 - accuracy: 0.9702 - val_loss: 0.8563 - val_accuracy: 0.8106
#
# Epoch 00166: saving model to saved_models\audio_classification.hdf5
# Epoch 167/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3175 - accuracy: 0.9802 - val_loss: 1.0187 - val_accuracy: 0.7879
#
# Epoch 00167: saving model to saved_models\audio_classification.hdf5
# Epoch 168/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2883 - accuracy: 0.9921 - val_loss: 0.8727 - val_accuracy: 0.8409
#
# Epoch 00168: saving model to saved_models\audio_classification.hdf5
# Epoch 169/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3152 - accuracy: 0.9861 - val_loss: 1.0529 - val_accuracy: 0.8182
#
# Epoch 00169: saving model to saved_models\audio_classification.hdf5
# Epoch 170/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3525 - accuracy: 0.9841 - val_loss: 0.8128 - val_accuracy: 0.8258
#
# Epoch 00170: saving model to saved_models\audio_classification.hdf5
# Epoch 171/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3106 - accuracy: 0.9861 - val_loss: 1.1507 - val_accuracy: 0.7879
#
# Epoch 00171: saving model to saved_models\audio_classification.hdf5
# Epoch 172/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3337 - accuracy: 0.9722 - val_loss: 0.8406 - val_accuracy: 0.8485
#
# Epoch 00172: saving model to saved_models\audio_classification.hdf5
# Epoch 173/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3274 - accuracy: 0.9782 - val_loss: 1.0563 - val_accuracy: 0.7955
#
# Epoch 00173: saving model to saved_models\audio_classification.hdf5
# Epoch 174/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3177 - accuracy: 0.9861 - val_loss: 1.0297 - val_accuracy: 0.7955
#
# Epoch 00174: saving model to saved_models\audio_classification.hdf5
# Epoch 175/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3019 - accuracy: 0.9881 - val_loss: 1.2019 - val_accuracy: 0.7576
#
# Epoch 00175: saving model to saved_models\audio_classification.hdf5
# Epoch 176/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3173 - accuracy: 0.9821 - val_loss: 0.9486 - val_accuracy: 0.8258
#
# Epoch 00176: saving model to saved_models\audio_classification.hdf5
# Epoch 177/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3250 - accuracy: 0.9821 - val_loss: 0.9757 - val_accuracy: 0.8258
#
# Epoch 00177: saving model to saved_models\audio_classification.hdf5
# Epoch 178/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3137 - accuracy: 0.9861 - val_loss: 0.8122 - val_accuracy: 0.8409
#
# Epoch 00178: saving model to saved_models\audio_classification.hdf5
# Epoch 179/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3058 - accuracy: 0.9921 - val_loss: 1.3484 - val_accuracy: 0.7652
#
# Epoch 00179: saving model to saved_models\audio_classification.hdf5
# Epoch 180/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3345 - accuracy: 0.9802 - val_loss: 0.7963 - val_accuracy: 0.8561
#
# Epoch 00180: saving model to saved_models\audio_classification.hdf5
# Epoch 181/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3066 - accuracy: 0.9841 - val_loss: 0.9263 - val_accuracy: 0.8106
#
# Epoch 00181: saving model to saved_models\audio_classification.hdf5
# Epoch 182/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2957 - accuracy: 0.9921 - val_loss: 0.8395 - val_accuracy: 0.8258
#
# Epoch 00182: saving model to saved_models\audio_classification.hdf5
# Epoch 183/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3068 - accuracy: 0.9881 - val_loss: 0.8498 - val_accuracy: 0.8333
#
# Epoch 00183: saving model to saved_models\audio_classification.hdf5
# Epoch 184/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3217 - accuracy: 0.9821 - val_loss: 1.0073 - val_accuracy: 0.7576
#
# Epoch 00184: saving model to saved_models\audio_classification.hdf5
# Epoch 185/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2970 - accuracy: 0.9901 - val_loss: 0.8157 - val_accuracy: 0.8258
#
# Epoch 00185: saving model to saved_models\audio_classification.hdf5
# Epoch 186/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3463 - accuracy: 0.9782 - val_loss: 0.8667 - val_accuracy: 0.8561
#
# Epoch 00186: saving model to saved_models\audio_classification.hdf5
# Epoch 187/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3102 - accuracy: 0.9841 - val_loss: 0.7983 - val_accuracy: 0.8030
#
# Epoch 00187: saving model to saved_models\audio_classification.hdf5
# Epoch 188/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3148 - accuracy: 0.9921 - val_loss: 0.7030 - val_accuracy: 0.8409
#
# Epoch 00188: saving model to saved_models\audio_classification.hdf5
# Epoch 189/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2985 - accuracy: 0.9921 - val_loss: 0.8623 - val_accuracy: 0.8258
#
# Epoch 00189: saving model to saved_models\audio_classification.hdf5
# Epoch 190/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2780 - accuracy: 0.9940 - val_loss: 0.7636 - val_accuracy: 0.8712
#
# Epoch 00190: saving model to saved_models\audio_classification.hdf5
# Epoch 191/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3038 - accuracy: 0.9861 - val_loss: 1.0242 - val_accuracy: 0.8030
#
# Epoch 00191: saving model to saved_models\audio_classification.hdf5
# Epoch 192/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2859 - accuracy: 0.9921 - val_loss: 0.7737 - val_accuracy: 0.8106
#
# Epoch 00192: saving model to saved_models\audio_classification.hdf5
# Epoch 193/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2859 - accuracy: 0.9901 - val_loss: 0.9996 - val_accuracy: 0.7879
#
# Epoch 00193: saving model to saved_models\audio_classification.hdf5
# Epoch 194/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2682 - accuracy: 0.9960 - val_loss: 0.8601 - val_accuracy: 0.8258
#
# Epoch 00194: saving model to saved_models\audio_classification.hdf5
# Epoch 195/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2664 - accuracy: 0.9940 - val_loss: 0.8442 - val_accuracy: 0.8409
#
# Epoch 00195: saving model to saved_models\audio_classification.hdf5
# Epoch 196/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2498 - accuracy: 0.9980 - val_loss: 1.0447 - val_accuracy: 0.7879
#
# Epoch 00196: saving model to saved_models\audio_classification.hdf5
# Epoch 197/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2477 - accuracy: 0.9980 - val_loss: 0.7502 - val_accuracy: 0.8409
#
# Epoch 00197: saving model to saved_models\audio_classification.hdf5
# Epoch 198/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2363 - accuracy: 1.0000 - val_loss: 0.7389 - val_accuracy: 0.8636
#
# Epoch 00198: saving model to saved_models\audio_classification.hdf5
# Epoch 199/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2429 - accuracy: 0.9980 - val_loss: 1.0453 - val_accuracy: 0.7803
#
# Epoch 00199: saving model to saved_models\audio_classification.hdf5
# Epoch 200/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2508 - accuracy: 0.9881 - val_loss: 0.7826 - val_accuracy: 0.8485
#
# Epoch 00200: saving model to saved_models\audio_classification.hdf5
# Epoch 201/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2380 - accuracy: 0.9960 - val_loss: 0.7002 - val_accuracy: 0.8485
#
# Epoch 00201: saving model to saved_models\audio_classification.hdf5
# Epoch 202/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2334 - accuracy: 0.9960 - val_loss: 0.6727 - val_accuracy: 0.8788
#
# Epoch 00202: saving model to saved_models\audio_classification.hdf5
# Epoch 203/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2464 - accuracy: 0.9940 - val_loss: 0.9307 - val_accuracy: 0.7879
#
# Epoch 00203: saving model to saved_models\audio_classification.hdf5
# Epoch 204/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2279 - accuracy: 0.9960 - val_loss: 0.6698 - val_accuracy: 0.8485
#
# Epoch 00204: saving model to saved_models\audio_classification.hdf5
# Epoch 205/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2328 - accuracy: 0.9901 - val_loss: 0.7882 - val_accuracy: 0.8182
#
# Epoch 00205: saving model to saved_models\audio_classification.hdf5
# Epoch 206/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2318 - accuracy: 0.9901 - val_loss: 0.7423 - val_accuracy: 0.8485
#
# Epoch 00206: saving model to saved_models\audio_classification.hdf5
# Epoch 207/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2202 - accuracy: 0.9940 - val_loss: 0.7897 - val_accuracy: 0.8409
#
# Epoch 00207: saving model to saved_models\audio_classification.hdf5
# Epoch 208/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2142 - accuracy: 0.9980 - val_loss: 0.9439 - val_accuracy: 0.8106
#
# Epoch 00208: saving model to saved_models\audio_classification.hdf5
# Epoch 209/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2089 - accuracy: 1.0000 - val_loss: 0.7659 - val_accuracy: 0.8561
#
# Epoch 00209: saving model to saved_models\audio_classification.hdf5
# Epoch 210/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2018 - accuracy: 1.0000 - val_loss: 0.7493 - val_accuracy: 0.8561
#
# Epoch 00210: saving model to saved_models\audio_classification.hdf5
# Epoch 211/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1988 - accuracy: 1.0000 - val_loss: 0.7865 - val_accuracy: 0.8485
#
# Epoch 00211: saving model to saved_models\audio_classification.hdf5
# Epoch 212/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1946 - accuracy: 0.9960 - val_loss: 0.7590 - val_accuracy: 0.8561
#
# Epoch 00212: saving model to saved_models\audio_classification.hdf5
# Epoch 213/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1938 - accuracy: 0.9960 - val_loss: 0.8073 - val_accuracy: 0.8561
#
# Epoch 00213: saving model to saved_models\audio_classification.hdf5
# Epoch 214/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2000 - accuracy: 0.9960 - val_loss: 0.6330 - val_accuracy: 0.8636
#
# Epoch 00214: saving model to saved_models\audio_classification.hdf5
# Epoch 215/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1894 - accuracy: 0.9980 - val_loss: 0.6786 - val_accuracy: 0.8636
#
# Epoch 00215: saving model to saved_models\audio_classification.hdf5
# Epoch 216/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1865 - accuracy: 1.0000 - val_loss: 0.6741 - val_accuracy: 0.8636
#
# Epoch 00216: saving model to saved_models\audio_classification.hdf5
# Epoch 217/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1821 - accuracy: 0.9980 - val_loss: 0.7565 - val_accuracy: 0.8485
#
# Epoch 00217: saving model to saved_models\audio_classification.hdf5
# Epoch 218/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1847 - accuracy: 0.9960 - val_loss: 0.6226 - val_accuracy: 0.8939
#
# Epoch 00218: saving model to saved_models\audio_classification.hdf5
# Epoch 219/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1779 - accuracy: 1.0000 - val_loss: 0.7417 - val_accuracy: 0.8485
#
# Epoch 00219: saving model to saved_models\audio_classification.hdf5
# Epoch 220/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1763 - accuracy: 0.9980 - val_loss: 0.6058 - val_accuracy: 0.8636
#
# Epoch 00220: saving model to saved_models\audio_classification.hdf5
# Epoch 221/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1729 - accuracy: 1.0000 - val_loss: 0.7095 - val_accuracy: 0.8636
#
# Epoch 00221: saving model to saved_models\audio_classification.hdf5
# Epoch 222/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1685 - accuracy: 1.0000 - val_loss: 0.7533 - val_accuracy: 0.8636
#
# Epoch 00222: saving model to saved_models\audio_classification.hdf5
# Epoch 223/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1874 - accuracy: 0.9921 - val_loss: 0.8089 - val_accuracy: 0.8258
#
# Epoch 00223: saving model to saved_models\audio_classification.hdf5
# Epoch 224/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1708 - accuracy: 0.9960 - val_loss: 0.8971 - val_accuracy: 0.8409
#
# Epoch 00224: saving model to saved_models\audio_classification.hdf5
# Epoch 225/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1750 - accuracy: 0.9921 - val_loss: 0.6491 - val_accuracy: 0.8561
#
# Epoch 00225: saving model to saved_models\audio_classification.hdf5
# Epoch 226/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1743 - accuracy: 0.9940 - val_loss: 0.8458 - val_accuracy: 0.8182
#
# Epoch 00226: saving model to saved_models\audio_classification.hdf5
# Epoch 227/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1919 - accuracy: 0.9940 - val_loss: 1.0594 - val_accuracy: 0.8106
#
# Epoch 00227: saving model to saved_models\audio_classification.hdf5
# Epoch 228/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2437 - accuracy: 0.9762 - val_loss: 0.6352 - val_accuracy: 0.8561
#
# Epoch 00228: saving model to saved_models\audio_classification.hdf5
# Epoch 229/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2503 - accuracy: 0.9762 - val_loss: 1.1329 - val_accuracy: 0.7652
#
# Epoch 00229: saving model to saved_models\audio_classification.hdf5
# Epoch 230/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2600 - accuracy: 0.9702 - val_loss: 0.9146 - val_accuracy: 0.7803
#
# Epoch 00230: saving model to saved_models\audio_classification.hdf5
# Epoch 231/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2608 - accuracy: 0.9782 - val_loss: 0.8948 - val_accuracy: 0.8333
#
# Epoch 00231: saving model to saved_models\audio_classification.hdf5
# Epoch 232/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2862 - accuracy: 0.9802 - val_loss: 1.0122 - val_accuracy: 0.8030
#
# Epoch 00232: saving model to saved_models\audio_classification.hdf5
# Epoch 233/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2737 - accuracy: 0.9821 - val_loss: 1.1253 - val_accuracy: 0.7803
#
# Epoch 00233: saving model to saved_models\audio_classification.hdf5
# Epoch 234/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2871 - accuracy: 0.9821 - val_loss: 0.7300 - val_accuracy: 0.8182
#
# Epoch 00234: saving model to saved_models\audio_classification.hdf5
# Epoch 235/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2548 - accuracy: 0.9940 - val_loss: 0.7109 - val_accuracy: 0.8561
#
# Epoch 00235: saving model to saved_models\audio_classification.hdf5
# Epoch 236/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2636 - accuracy: 0.9861 - val_loss: 0.7277 - val_accuracy: 0.8333
#
# Epoch 00236: saving model to saved_models\audio_classification.hdf5
# Epoch 237/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2442 - accuracy: 0.9980 - val_loss: 0.7029 - val_accuracy: 0.8636
#
# Epoch 00237: saving model to saved_models\audio_classification.hdf5
# Epoch 238/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2638 - accuracy: 0.9901 - val_loss: 1.1406 - val_accuracy: 0.8106
#
# Epoch 00238: saving model to saved_models\audio_classification.hdf5
# Epoch 239/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2602 - accuracy: 0.9921 - val_loss: 0.9318 - val_accuracy: 0.8258
#
# Epoch 00239: saving model to saved_models\audio_classification.hdf5
# Epoch 240/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2554 - accuracy: 0.9940 - val_loss: 0.9968 - val_accuracy: 0.8030
#
# Epoch 00240: saving model to saved_models\audio_classification.hdf5
# Epoch 241/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2587 - accuracy: 0.9901 - val_loss: 0.7551 - val_accuracy: 0.8561
#
# Epoch 00241: saving model to saved_models\audio_classification.hdf5
# Epoch 242/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2436 - accuracy: 0.9921 - val_loss: 0.8219 - val_accuracy: 0.8106
#
# Epoch 00242: saving model to saved_models\audio_classification.hdf5
# Epoch 243/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2481 - accuracy: 0.9940 - val_loss: 0.7950 - val_accuracy: 0.8561
#
# Epoch 00243: saving model to saved_models\audio_classification.hdf5
# Epoch 244/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2498 - accuracy: 0.9901 - val_loss: 0.8756 - val_accuracy: 0.8258
#
# Epoch 00244: saving model to saved_models\audio_classification.hdf5
# Epoch 245/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2385 - accuracy: 0.9921 - val_loss: 0.7690 - val_accuracy: 0.8636
#
# Epoch 00245: saving model to saved_models\audio_classification.hdf5
# Epoch 246/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2247 - accuracy: 0.9960 - val_loss: 0.7988 - val_accuracy: 0.8409
#
# Epoch 00246: saving model to saved_models\audio_classification.hdf5
# Epoch 247/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2284 - accuracy: 0.9940 - val_loss: 1.0091 - val_accuracy: 0.8333
#
# Epoch 00247: saving model to saved_models\audio_classification.hdf5
# Epoch 248/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2284 - accuracy: 0.9940 - val_loss: 1.1122 - val_accuracy: 0.7803
#
# Epoch 00248: saving model to saved_models\audio_classification.hdf5
# Epoch 249/250
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2674 - accuracy: 0.9861 - val_loss: 0.8342 - val_accuracy: 0.8636
#
# Epoch 00249: saving model to saved_models\audio_classification.hdf5
# Epoch 250/250
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2561 - accuracy: 0.9881 - val_loss: 0.9551 - val_accuracy: 0.8636
#
# Epoch 00250: saving model to saved_models\audio_classification.hdf5
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9551 - accuracy: 0.8636
# Test loss: 0.9550808072090149
# Test accuracy: 0.8636363744735718
# Training completed in time:  0:01:06.448988

# %%
filename="cough.wav"

y, sr = librosa.load(filename, duration=4) 
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps = librosa.power_to_db(ps, ref=np.max) # Converts melspectogram into dB instead of Amplitude squared

ps=ps.reshape(1,ps.shape[0],ps.shape[1],1)
#ps.shape

#predicted_label=model.predict_classes(ps) #deprecated
predicted_label=np.argmax(model.predict(ps),axis=-1)
#print(predicted_label)

prediction_class = labelencoder.inverse_transform(predicted_label) 
prediction_class
# Out:
# array([1])

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# %%
#y_pred=model.predict_classes(X_test)
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# %%
class_names=["cough","sneeze","other"]

# %%
#mat=confusion_matrix(y_test,y_pred)
mat=confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))

plot_confusion_matrix(conf_mat=mat,class_names=class_names,show_normed=True)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)
